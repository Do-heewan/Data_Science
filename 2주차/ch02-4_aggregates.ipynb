# %%
import numpy as np

# %%
rng = np.random.default_rng()

L = rng.random(100)
sum(L)
# Out:
# 52.176860891503786

# %%
np.sum(L)
# Out:
# 52.17686089150379

# %%
big_array = rng.random(100000)

# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 7.17 ms ± 96.2 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30.4 μs ± 687 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# # Multidimensional Aggregates

# %%
M = rng.integers(0, 10, (3, 4))
print(M)
# Out:
# [[9 7 6 8]
#  [3 6 1 3]
#  [3 3 8 6]]

# %%
M.min(axis = 0) # 행 방향 -> 위에서 아래로
# Out:
# array([3, 3, 1, 3], dtype=int64)

# %%
M.min(axis = 1) # 열 방향 -> 왼쪽에서 오른쪽으로
# Out:
# array([6, 1, 3], dtype=int64)

# %% [markdown]
# ### NaN-Safe version : NaN값을 제외한 실수들만 계산
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Example : Presients Height

# %%
# !head -4 president_heights.csv
# Out:
# 'head'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('president_heights.csv')
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print(f"Mean height : {heights.mean()}")
print(f"Standard deviation : {heights.std()}")
print(f"Min : {heights.min()}")
print(f"max : {heights.max()}")
# Out:
# Mean height : 179.73809523809524
# Standard deviation : 6.931843442745892
# Min : 163
# max : 193

# %%
data.head()
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163
# 4      5       James Monroe         183
