# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np

# %% [markdown]
# # 3차원 함수 시각화

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y) # 0 ~ 5 까지 50개, 40개의 수 배열 만들어 줌
Z = f(X, Y)

plt.figure(figsize = (17, 5))

plt.subplot(1, 3, 1)
plt.contour(X, Y, Z, colors='black') # color or cmap 하나 사용

plt.subplot(1, 3, 2)
plt.contour(X, Y, Z, 20, cmap = 'RdGy') # RedGray

plt.subplot(1, 3, 3)
plt.contourf(X, Y, Z)

plt.show()

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       1 plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
#       2            cmap='RdGy')
#       3 plt.colorbar()
# ----> 4 plt.axis(aspect='image')
#       5 plt.show()
#
# File c:\Users\Noh\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2915, in axis(arg, emit, **kwargs)
#    2907 @_copy_docstring_and_deprecators(Axes.axis)
#    2908 def axis(
#    2909     arg: tuple[float, float, float, float] | bool | str | None = None,
#    (...)
#    2913     **kwargs,
#    2914 ) -> tuple[float, float, float, float]:
# -> 2915     return gca().axis(arg, emit=emit, **kwargs)
#
# File c:\Users\Noh\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2163, in _AxesBase.axis(self, arg, emit, **kwargs)
#    2161         set_ax_lim(ax_min, ax_max, emit=emit, auto=ax_auto)
#    2162 if kwargs:
# -> 2163     raise _api.kwarg_error("axis", kwargs)
#    2164 lims = ()
#    2165 for name in self._axis_names:
#
# TypeError: axis() got an unexpected keyword argument 'aspect'

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar()
plt.show()
